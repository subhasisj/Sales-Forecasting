# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split
from pycaret.regression import *

# %%
sales_df = pd.read_csv('./Data/train_data_with_ts.csv')

# %%
sales_df.head()
# Out:
#    year_week  recipe_id                 recipe_name product_type  calories  \
# 0     201801      14919  Shrimp &amp; Broccoli Stir-Fry     2 person     687.0
# 1     201801      14920   Caramelized Cabbage Pasta     2 person     779.0
# 2     201801      14449     AFC Vegetarian Pad Thai     z_amazon     642.0
# 3     201801      11963  Shrimp &amp; Broccoli Stir-Fry       family     620.0
# 4     201801      14914        Chicken &amp; Pasta Soup       family     610.0
#
#    carbs  cooking_time       cuisine  \
# 0   99.2  time_level_4         asian
# 1   81.3  time_level_4  new_american
# 2   92.8           NaN           NaN
# 3   93.2  time_level_4         asian
# 4   67.0  time_level_4  new_american
#
#                                          description difficulty  ... proteins  \
# 0  For this dish, once the ingredients are preppe...       easy  ...     29.5
# 1  Red lentil penne makes this pasta dish a pleas...       easy  ...     30.0
# ...

# %%
# train_sales_df = sales_df.sample(frac=0.75, random_state=42).reset_index(drop=True)
# test_sales_df = sales_df.drop(sales_df.index).reset_index(drop=True)

train_sales_df, test_sales_df = train_test_split(sales_df,test_size=0.33, random_state=42)

# %%
print('Data for Modeling: ' + str(train_sales_df.shape))
print('Unseen Data For Predictions: ' + str(test_sales_df.shape))
# Out:
# Data for Modeling: (1969, 30)
# Unseen Data For Predictions: (970, 30)

# %%
regression_models = setup(data = train_sales_df, target = 'sales', session_id=123)
# Out:
#
# Setup Succesfully Completed.
# &lt;pandas.io.formats.style.Styler at 0x2996015c460&gt;

# %%
xgb = create_model('xgboost')
# Out:
# &lt;pandas.io.formats.style.Styler at 0x29964aa4910&gt;

# %%
tuned_xgb = tune_model(xgb)
# Out:
# &lt;pandas.io.formats.style.Styler at 0x2996c2c2a30&gt;

# %%
ada = create_model('ada')
# Out:
# &lt;pandas.io.formats.style.Styler at 0x2995c61bd30&gt;

# %%
tuned_ada = tune_model(ada)
# Out:
# &lt;pandas.io.formats.style.Styler at 0x299000a9670&gt;

# %%
compare_models()
# Out:
# IntProgress(value=0, description=&#39;Processing: &#39;, max=251)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              01:08:01
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# ETC        . . . . . . . . . . . . . . . . . .       Calculating ETC
# Empty DataFrame
# Columns: [Model, MAE, MSE, RMSE, R2, RMSLE, MAPE, TT (Sec)]
# Index: []
# ---------------------------------------------------------------------------
# LightGBMError                             Traceback (most recent call last)
# &lt;ipython-input-26-9ff5ccfe3077&gt; in &lt;module&gt;
# ----&gt; 1 compare_models()
#
# ~\Anaconda3\envs\sales-forecasting\lib\site-packages\pycaret\regression.py in compare_models(exclude, include, fold, round, sort, n_select, budget_time, turbo, verbose)
#    2425             time_start=time.time()
#    2426             logger.info(&quot;Fitting Model&quot;)
# ...
